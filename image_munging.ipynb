# %%
'''keep consistant across all notebooks'''
import os
import pandas as pd
from PIL import Image 
import keras
import tensorflow
# Out:
# Using TensorFlow backend.

# %%
''' Outline for notebook:
<> - less important - after mvp
- checks csv for log if new file work on, add to log.
- unzip/transfer file into filtered folder if new zips/files found in keg
- if added to log and unuseable drop file
<> - less important - after mvp
- read all file.types in assets folder
- if file.type is usable skip
- if unusable convert


<> - Step 1
- record file names.type to report csv called input
- read usable files
- convert image to number array for image_nn
- write to csv called image_data
- if successful, write file name to report csv called retained
- compare size of input to retained
'''
# Out:
# ' Outline for notebook:\n<> - less important - after mvp\n- checks csv for log if new file work on, add to log.\n- unzip/transfer file into filtered folder if new zips/files found in keg\n- if added to log and unuseable drop file\n<> - less important - after mvp\n- read all file.types in assets folder\n- if file.type is usable skip\n- if unusable convert\n\n\n<> - Step 1\n- record file names.type to report csv called input\n- read usable files\n- convert image to number array for image_nn\n- write to csv called image_data\n- if successful, write file name to report csv called retained\n- compare size of input to retained\n'

# %%
'''
Marco's version
'''
# train_files = [f for f in glob.glob("./trainset/*")]
# cv2.imread(train_files[0])```
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image, ImageFilter
import random
import cv2
import os, glob
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # see the value of multiple statements at once.
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

train_peace = [image for image in glob.glob('./input/Marcel-Train/V/*')]
cv2.imread(train_peace[0])
# Out:
# array([[[216, 195, 193],
#         [218, 197, 195],
#         [213, 197, 198],
#         ...,
#         [234, 216, 215],
#         [224, 200, 194],
#         [214, 190, 184]],
#
#        [[220, 196, 196],
#         [222, 198, 198],
#         [214, 196, 197],
#         ...,
#         [236, 216, 215],
#         [226, 200, 194],
#         [216, 190, 184]],
#
#        [[218, 194, 194],
#         [219, 195, 195],
#         [211, 195, 196],
#         ...,
#         [230, 215, 213],
#         [220, 199, 191],
#         [212, 191, 183]],
#
#        ...,
#
#        [[186, 160, 154],
#         [188, 162, 156],
#         [188, 162, 156],
#         ...,
#         [ 27,  23,  28],
#         [ 28,  23,  32],
#         [ 27,  22,  31]],
#
#        [[190, 160, 155],
#         [190, 160, 155],
#         [192, 159, 156],
#         ...,
#         [ 27,  25,  25],
#         [ 28,  26,  26],
#         [ 27,  25,  25]],
#
#        [[206, 168, 164],
#         [205, 167, 163],
#         [206, 167, 165],
# ...

# %%
'''
looks in input folder for readable ppm files adds to list and writes list to csv. 
Upgrade to glob.glob after mvp for multiple file types
'''
fpath = '/Users/njume/documents/ga_dsi_nyc/capstones/ALS_translator/input/Marcel-Train/V'
loc_lst = [] # for list of files in folder
passthough = 0
scope = 0
for file in os.listdir(fpath):
    passthough += 1
    fname = '%s/%s' % (fpath, file)
    if os.path.isfile(fname) and file.endswith('.ppm'): # makes sure file worked with is in that spot.
        loc_lst.append(fname)
        scope =+ 1
#     if os.path.isfile(fname):
#         sense += 1
#     if os.path.isfile(fname) and file.endswith('.txt'):  # reach file & check for extension
#         with open(fname) as f:                           # ()can't figure out why this rename is necessary
#             for i in projects:                           # anything within the range of projects[]
#                 if i in fname.lower():                   # if object in file name.. and forces file name to lowercase
#                     project_type = str(i)                # ask for an example of making projects.upper version
#                     print('Text')
# Out:
# '\nlooks in input folder for readable ppm files adds to list and writes list to csv. \nUpgrade to glob.glob after mvp for multiple file types\n'

# %%
# for image in loc_lst:
#     fname = '%s/%s' % (fpath, image)
#     with open(fname) as f:
#         print(fname)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-ab4cfc69c593> in <module>()
#       1 for image in loc_lst:
#       2     fname = '%s/%s' % (fpath, image)
# ----> 3     with open(fname) as f:
#       4         print(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/njume/documents/ga_dsi_nyc/capstones/ALS_translator/input/Marcel-Train/V//Users/njume/documents/ga_dsi_nyc/capstones/ALS_translator/input/Marcel-Train/V/V-train296.ppm'

# %%
train_peace = [image for image in glob.glob('./input/Marcel-Train/V/*')]
len(train_peace)
# Out:
# 1395

# %%
train_HF = [image for image in glob.glob('./input/Marcel-Train/Five/*')]
len(train_peace)
# Out:
# 654

# %%
train_B = [image for image in glob.glob('./input/Marcel-Train/B/*')]
len(train_peace)
# Out:
# 487

# %%
train_V = [image for image in glob.glob('./input/Marcel-Train/V/*')]
len(train_peace)
# Out:
# 435

# %%
train_A = [image for image in glob.glob('./input/Marcel-Train/A/*')]
len(train_peace)
# Out:
# 1329

# %%
train_C = [image for image in glob.glob('./input/Marcel-Train/C/*')]
len(train_peace)
# Out:
# 572

# %%
hand = cv2.imread(train_peace[0])
# cv2.imshow('first hand', hand)
# k = cv2.waitKey(0)
# if k == 27:         # wait for ESC key to exit
#     cv2.destroyAllWindows()
# elif k == ord('s'): # wait for 's' key to save and exit
#     cv2.imwrite('messigray.png',img)
#     cv2.destroyAllWindows()
#     cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
cv2.imread(loc_lst[0]).shape

# %%
loc_lst[0], train_peace[0] # my old way, marco's kaggle way

# %%
extra = pd.read_csv('./input/sign-language-mnist/sign_mnist_train.csv')
extra.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  pixel10  pixel11  pixel12  pixel13  pixel14  pixel15  pixel16  \
# 0     153      156      158      160      163      165      159      166
# 1     158      157      158      156      154      154      153      152
# 2     187      186      185      185      185      184      184      184
# 3     210      211      209      207      208      207      206      203
# 4     185      186      188      189      189      190      191      189
#
#    pixel17  pixel18  pixel19  pixel20  pixel21  pixel22  pixel23  pixel24  \
# ...
